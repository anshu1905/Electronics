# %%
#importing all the libraries required for explanatory data analysis(EDA)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset(csv file) that is diabetes.csv into a variable data
data=pd.read_csv('diabetes.csv')
# Out:
# Enter a number0
# Enter a number0

# %%
#top 5 data values
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#bottom 5 data values
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#represents the size of the data
#there are 768 rows and 9 columns
data.shape
# Out:
# (768, 9)

# %%
#provides statistical data of each column 
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#all the data labels
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#information of data type ,null,count,etc.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#replace all nan value with mean of the columns
data.fillna(data.mean())
data.isnull().mean()
# Out:
# Pregnancies                 0.0
# Glucose                     0.0
# BloodPressure               0.0
# SkinThickness               0.0
# Insulin                     0.0
# BMI                         0.0
# DiabetesPedigreeFunction    0.0
# Age                         0.0
# Outcome                     0.0
# dtype: float64

# %%
#Generate a report of the entire data 
import pandas_profiling as pp

pp.ProfileReport(data)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
#plot histogram(frequency distribution) of each label
# %matplotlib inline
data.hist(figsize=(15,15),color="#31CFB3",bins=5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002038EE6E908>,
# ...
#       dtype=object)

# %%
#generate area plot for all data labels
# %matplotlib inline
data.plot(kind='area', subplots=True, layout=(3,3), sharex=False , figsize =(15,15))
plt.show()
# Out:
# c:\users\anshuman\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\anshuman\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\anshuman\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:314: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
# ...

# %%
#generate density plot for all data labels
# %matplotlib inline
data.plot(kind='density', subplots=True, layout=(3,3), sharex=False , figsize =(15,15))
plt.show()
# Out:
# c:\users\anshuman\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\anshuman\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\anshuman\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:314: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
# ...

# %%
#find the correlation between different labels
correlation=data.corr()
print(correlation)
#generate a heatmap for the same
sns.heatmap(correlation, annot=True,linewidths=.5,   xticklabels=correlation.columns, 
         yticklabels=correlation.columns, linecolor='white', cbar=True)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
#generate bar plot to get the relation between outcome and rest of the data labels

plt.figure(figsize=(15,15))

plt.subplot(3,3,1)
sns.barplot(data=data,y='Pregnancies',x='Outcome',hue='Outcome')

plt.subplot(3,3,2)
sns.barplot(data=data,y='Glucose',x='Outcome',hue='Outcome')

plt.subplot(3,3,3)
sns.barplot(data=data,y='BloodPressure',x='Outcome',hue='Outcome')

plt.subplot(3,3,4)
sns.barplot(data=data,y='SkinThickness',x='Outcome',hue='Outcome')

plt.subplot(3,3,5)
sns.barplot(data=data,y='Insulin',x='Outcome',hue='Outcome')

plt.subplot(3,3,6)
sns.barplot(data=data,y='BMI',x='Outcome',hue='Outcome')

plt.subplot(3,3,7)
sns.barplot(data=data,y='DiabetesPedigreeFunction',x='Outcome',hue='Outcome')

plt.subplot(3,3,8)
sns.barplot(data=data,y='Age',x='Outcome',hue='Outcome')

# %%
#generate a swarm plot for all data labels against outcome

plt.figure(figsize=(15,15))

plt.subplot(3,3,1)
sns.swarmplot(data=data,y='Pregnancies',x='Outcome',hue='Outcome')

plt.subplot(3,3,2)
sns.swarmplot(data=data,y='Glucose',x='Outcome',hue='Outcome')

plt.subplot(3,3,3)
sns.swarmplot(data=data,y='BloodPressure',x='Outcome',hue='Outcome')

plt.subplot(3,3,4)
sns.swarmplot(data=data,y='SkinThickness',x='Outcome',hue='Outcome')

plt.subplot(3,3,5)
sns.swarmplot(data=data,y='Insulin',x='Outcome',hue='Outcome')

plt.subplot(3,3,6)
sns.swarmplot(data=data,y='BMI',x='Outcome',hue='Outcome')

plt.subplot(3,3,7)
sns.swarmplot(data=data,y='DiabetesPedigreeFunction',x='Outcome',hue='Outcome')

plt.subplot(3,3,8)
sns.swarmplot(data=data,y='Age',x='Outcome',hue='Outcome')

# %%
#generate a violin plot for all data labels against outcome

plt.figure(figsize=(15,15))

plt.subplot(3,3,1)
sns.violinplot(data=data,y='Pregnancies',x='Outcome',hue='Outcome')

plt.subplot(3,3,2)
sns.violinplot(data=data,y='Glucose',x='Outcome',hue='Outcome')

plt.subplot(3,3,3)
sns.violinplot(data=data,y='BloodPressure',x='Outcome',hue='Outcome')

plt.subplot(3,3,4)
sns.violinplot(data=data,y='SkinThickness',x='Outcome',hue='Outcome')

plt.subplot(3,3,5)
sns.violinplot(data=data,y='Insulin',x='Outcome',hue='Outcome')

plt.subplot(3,3,6)
sns.violinplot(data=data,y='BMI',x='Outcome',hue='Outcome')

plt.subplot(3,3,7)
sns.violinplot(data=data,y='DiabetesPedigreeFunction',x='Outcome',hue='Outcome')

plt.subplot(3,3,8)
sns.violinplot(data=data,y='Age',x='Outcome',hue='Outcome')

# %%
#generate a box plot for all data labels against outcome

plt.figure(figsize=(15,15))

plt.subplot(3,3,1)
sns.boxplot(data=data,y='Pregnancies')

plt.subplot(3,3,2)
sns.boxplot(data=data,y='Glucose')

plt.subplot(3,3,3)
sns.boxplot(data=data,y='BloodPressure')

plt.subplot(3,3,4)
sns.boxplot(data=data,y='SkinThickness')

plt.subplot(3,3,5)
sns.boxplot(data=data,y='Insulin')

plt.subplot(3,3,6)
sns.boxplot(data=data,y='BMI')

plt.subplot(3,3,7)
sns.boxplot(data=data,y='DiabetesPedigreeFunction')

plt.subplot(3,3,8)
sns.boxplot(data=data,y='Age')

# %%
#generate a line plot for all data labels against outcome

plt.figure(figsize=(15,15))

plt.subplot(3,3,1)
sns.lineplot(data=data,y='Pregnancies',x='Outcome')

plt.subplot(3,3,2)
sns.lineplot(data=data,y='Glucose',x='Outcome')

plt.subplot(3,3,3)
sns.lineplot(data=data,y='BloodPressure',x='Outcome')

plt.subplot(3,3,4)
sns.lineplot(data=data,y='SkinThickness',x='Outcome')

plt.subplot(3,3,5)
sns.lineplot(data=data,y='Insulin',x='Outcome')

plt.subplot(3,3,6)
sns.lineplot(data=data,y='BMI',x='Outcome')

plt.subplot(3,3,7)
sns.lineplot(data=data,y='DiabetesPedigreeFunction',x='Outcome')

plt.subplot(3,3,8)
sns.lineplot(data=data,y='Age',x='Outcome')

# %%
#generate a regression plot for all data labels against outcome

plt.figure(figsize=(15,15))

plt.subplot(3,3,1)
sns.regplot(data=data,x='Pregnancies',y='Outcome')

plt.subplot(3,3,2)
sns.regplot(data=data,x='Glucose',y='Outcome')

plt.subplot(3,3,3)
sns.regplot(data=data,x='BloodPressure',y='Outcome')

plt.subplot(3,3,4)
sns.regplot(data=data,x='SkinThickness',y='Outcome')

plt.subplot(3,3,5)
sns.regplot(data=data,x='Insulin',y='Outcome')

plt.subplot(3,3,6)
sns.regplot(data=data,x='BMI',y='Outcome')

plt.subplot(3,3,7)
sns.regplot(data=data,x='DiabetesPedigreeFunction',y='Outcome')

plt.subplot(3,3,8)
sns.regplot(data=data,x='Age',y='Outcome')

# %%
#generate a distribution plot for all data labels 

plt.figure(figsize=(15,15))

plt.subplot(3,3,1)
preg=np.array(data['Pregnancies'])
sns.distplot(preg)

plt.subplot(3,3,2)
glucose=np.array(data['Glucose'])
sns.distplot(glucose)

plt.subplot(3,3,3)
bp=np.array(data['BloodPressure'])
sns.distplot(bp)

plt.subplot(3,3,4)
st=np.array(data['SkinThickness'])
sns.distplot(st)

plt.subplot(3,3,5)
i=np.array(data['Insulin'])
sns.distplot(i)

plt.subplot(3,3,6)
bmi=np.array(data['BMI'])
sns.distplot(bmi)

plt.subplot(3,3,7)
dpf=np.array(data['DiabetesPedigreeFunction'])
sns.distplot(dpf)

plt.subplot(3,3,8)
age=np.array(data['Age'])
sns.distplot(age)

# %%
plt.figure(figsize=(30, 30))
sns.pairplot(data,hue='Outcome',height=3, diag_kind='hist')

# %%
plt.figure(figsize=(30, 30))
sns.pairplot(data,height=3, diag_kind='kde')
